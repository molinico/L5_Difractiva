# %% [markdown]
# # L5 G1 Espectroscopía difractiva

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import time
import scipy.signal
from scipy.optimize import curve_fit
import scipy.stats as stats
import pandas as pd
import os
from  scipy.stats import chi2_contingency
from statsmodels.stats.weightstats import DescrStatsW

#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos')


#get_ipython().run_line_magic('matplotlib', 'inline')
get_ipython().run_line_magic('matplotlib', 'qt5')

# %% [markdown]
# ## Espectros de elementos

# %% [markdown]
# ### Hidrógeno Z=1

# %%
plt.close("all")
Z=1

#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\espectroscopia')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\espectroscopia')

file1='H 18 ms.txt'
file2='H 300 ms.txt'
file3='H 400 ms.txt'
file4='H 400 ms.txt'
file5='H mejor 20ms.csv'
file6='H mejor 500ms.txt'

H_20ms = np.loadtxt(file5, delimiter=',', skiprows=0, unpack=True)
H_500ms=np.loadtxt(file6, delimiter=',', skiprows=0, unpack=True)


archivos=[H_20ms,H_500ms]
tiemposint=["20ms","500ms"]
titulos=["Hidr+ogeno 50ms","Hidrógeno 500ms"]

j=0
k=0
for j in archivos:
     wl_H=j[0]
     i_H=j[1]
     

     plt.figure()
     plt.grid()
     plt.axvline(x=435.58,linewidth=0.6,c="red",label="Lineas de Balmer")
     plt.axvline(x=487.084,linewidth=0.6,c="red")
     plt.axvline(x=657.6015,linewidth=0.6,c="red")
     plt.title(titulos[k])
     plt.plot(wl_H,i_H,label="Espectro")
     plt.xlabel("Longitud de onda (nm)")
     plt.ylabel("Intensidad")
     plt.legend()
     k=k+1
    
wlmax_H=[435.58,487.084,657.6015]
x=np.linspace(0,0.15,10)
y=[10**9*1/(435.58),10**9*1/487.084,10**9*1/657.6015]   #paso a metros 
#1/wlmax_H
xwlmax_H=[1/25,1/16,1/9]
#1/lambda=-Rh*(1/4+1/n**2)

def balmer(x,Rh,b):
          y=Rh*Z**2*(1/4-x)+b
          return y

popt, pcov = curve_fit(balmer, xwlmax_H,y )    
perr = np.sqrt(np.diag(pcov))
valorRh= popt[0]
valorb=popt[1]

err_Rh = perr[0]
err_b=perr[1]

ajuste=balmer(x,valorRh,valorb)


plt.figure()
plt.grid()
plt.title("Ajuste lineal serie de Balmer del Hidrógeno")
plt.ylabel("1/$lambda$ [$m^{-1}$]")
plt.xlabel("1/$n^2$")
plt.scatter(xwlmax_H,y,label="Datos")
plt.plot(x,ajuste,c="red",label="ajuste")
plt.legend()


print("Rh=",valorRh,"+-",err_Rh,"en m^-1")
print("oo=",valorb,"+-",err_b)
print("proporcion valor dado con el real",valorRh/1.0973*10**(-7))
# Out:
# Rh= 10908226.822880449 +- 38765.78085169976 en m^-1
# oo= 6149.87561910366 +- 7025.996309005148
# proporcion valor dado con el real 0.994097040269794

# %% [markdown]
# ### Helio Z=2

# %%
plt.close("all")
Z=1

#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\espectroscopia')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\espectroscopia')

file1='He 5ms.csv'
file2='He 10ms.csv'
file3='He 30ms.txt'


He5ms= np.loadtxt(file1, delimiter=',', skiprows=0, unpack=True)
He10ms=np.loadtxt(file2, delimiter=',', skiprows=0, unpack=True)
He30ms=np.loadtxt(file3, delimiter=',', skiprows=0, unpack=True)


archivos=[He5ms,He10ms,He30ms]
tiemposint=["5ms","10ms","30ms"]

j=0
k=0
for j in archivos:
     wl_He=j[0]
     i_He=j[1]
     

     plt.figure()
     plt.grid()
     plt.title(tiemposint[k])
     plt.plot(wl_He,i_He)
     plt.xlabel("Longitud de onda (nm)")
     plt.ylabel("Intensidad")
     k=k+1


wlmax_He=[389.58,448.21,472.1,493.14,502.64,588.87,669.079,707.786,729.337]

wlmax_He_utiles=[448.21,493.14,669.079]

y_utiles=[10**(9)*1/448.21,10**(9)*1/493.14,10**(9)*1/669.079]


y=[10**9*1/(389.58),10**9*1/(448.21),10**9*1/472.1,10**9*1/493.14,10**9*1/502.64,10**9*1/588.87,10**9*1/669.079,10**9*1/707.786,10**9*1/729.337]   #paso a metros 

x=np.linspace(0,0.3,3)


#1/wlmax_H
xwlmax_He=[1/25,1/16,1/9]
#1/lambda=-Rh*(1/4+1/n**2)

def balmer(x,Rh,b):
          y=Rh*Z**2*(1/4-x)+b
          return y

popt, pcov = curve_fit(balmer, xwlmax_He,y_utiles )    
perr = np.sqrt(np.diag(pcov))
valorRh= popt[0]
valorb=popt[1]

err_Rh = perr[0]
err_b=perr[1]

ajuste=balmer(x,valorRh,valorb)


plt.figure()
plt.grid()
plt.ylabel("1/$\lambda$ [$m^{-1}$]")
plt.xlabel("1/$n^2$")
plt.scatter(xwlmax_He,y_utiles)
plt.plot(x,ajuste,c="red")


print("Rh=",valorRh,"+-",err_Rh,"en m^-1")
print("oo=",valorb,"+-",err_b)
print("proporcion valor dado con el real",valorRh/1.0973*10**(-7))
# Out:
# Rh= 10455142.25489707 +- 462451.68679727317 en m^-1
# oo= 48496.140036570956 +- 83815.8404582669
# proporcion valor dado con el real 0.9528061838054379

# %% [markdown]
# ### Argón Z=18

# %%
plt.close("all")
Z=1

#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\espectroscopia')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\espectroscopia')

file1='Ar 15ms.csv'
file2='Ar 20ms.csv'


Ar15= np.loadtxt(file1, delimiter=',', skiprows=0, unpack=True)
Ar20=np.loadtxt(file2, delimiter=',', skiprows=0, unpack=True)



archivos=[Ar15,Ar20]
tiemposint=["15ms","20ms"]

j=0
k=0
for j in archivos:
     wl_Ar=j[0]
     i_Ar=j[1]
     

     plt.figure()
     plt.grid()
     plt.title(tiemposint[k])
     plt.plot(wl_Ar,i_Ar)
     plt.xlabel("Longitud de onda (nm)")
     plt.ylabel("Intensidad")
     k=k+1



wlmax_Ar=[]

#wlmax_Ar_utiles=[746.8,750.4,751.5,763.5,772.4, 794.8,811.5, 826.5, 841.8, 842.5,853.6,866.8]
wlmax_Ar_utiles=[746.8,750.4,751.5,763.5,772.4, 794.8,811.5, 826.5]

#y_utiles=[10**(9)*1/746.8,10**(9)*1/750.4,10**(9)*1/751.5,10**(9)*1/763.5,10**(9)*1/772.4, 10**(9)*1/794.8,10**(9)*1/811.5, 10**(9)*1/826.5,10**(9)*1/ 841.8, 10**(9)*1/842.5,10**(9)*1/853.6,10**(9)*1/866.8]
y_utiles=[10**(9)*1/746.8,10**(9)*1/750.4,10**(9)*1/751.5,10**(9)*1/763.5,10**(9)*1/772.4, 10**(9)*1/794.8,10**(9)*1/811.5, 10**(9)*1/826.5]


x=np.linspace(0,0.04,8)
#

#1/wlmax_Ar
#xwlmax_Ar=[1/15**2,1/14**2,1/13**2,1/12**2,1/11**2,1/10**2,1/9**2,1/8**2,1/7**2,1/6**2,1/5**2,1/4**2]
xwlmax_Ar=[1/15**2,1/14**2,1/13**2,1/12**2,1/11**2,1/10**2,1/9**2,1/8**2]

def paschen(x,Rh,b):
          y=Rh*Z**2*(1/9-x)+b
          return y

popt, pcov = curve_fit(paschen, xwlmax_Ar,y_utiles )    
perr = np.sqrt(np.diag(pcov))
valorRh= popt[0]
valorb=popt[1]

err_Rh = perr[0]
err_b=perr[1]

ajuste=paschen(x,valorRh,valorb)


plt.figure()
plt.grid()
plt.title("Paschen series Argon")
plt.ylabel("1/$\lambda$ [$m^{-1}$]")
plt.xlabel("1/$n^2$")
plt.scatter(xwlmax_Ar,y_utiles)
plt.plot(x,ajuste,c="red")


print("Rh=",valorRh,"+-",err_Rh,"en m^-1")
print("oo=",valorb,"+-",err_b)
print("proporcion valor dado con el real",valorRh/1.0973*10**(-7))
# Out:
# Rh= 12582651.5541695 +- 814023.8539243682 en m^-1
# oo= -1714.3862654481782 +- 83514.83177797927
# proporcion valor dado con el real 1.146692021705049

# %% [markdown]
# ### Neón

# %%
plt.close("all")
Z=1

os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\espectroscopia')
#os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\espectroscopia')

file1='Ne 20ms.txt'



Ne= np.loadtxt(file1, delimiter=',', skiprows=0, unpack=True)


wl_Ne=Ne[0]
i_Ne=Ne[1]
     

plt.figure()
plt.grid()
plt.title("Neón 20ms")
plt.plot(wl_Ne,i_Ne)
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")






wlmax_Ne_utiles=[639.529, 632, 628.132, 623.127, 617.661, 611.074, 608.8]


#y_utiles=[10**(9)*1/639.529, 10**(9)*1/632, 10**(9)*1/628.132, 10**(9)*1/623.127, 10**(9)*1/617.661, 10**(9)*1/611.074, 10**(9)*1/608.8]
y_utiles=[ 10**(9)*1/632, 10**(9)*1/628.132, 10**(9)*1/623.127, 10**(9)*1/617.661, 10**(9)*1/611.074]


x=np.linspace(0,0.15,8)
#


#xwlmax_Ne=[1/9**2, 1/8**2,1/7**2, 1/6**2, 1/5**2, 1/4**2, 1/3**2]
xwlmax_Ne=[ 1/8**2,1/7**2, 1/6**2, 1/5**2, 1/4**2]


def sharp(x,Rh,b):
          y=Rh*Z**2*(1/4-x)+b
          return y

popt, pcov = curve_fit(sharp, xwlmax_Ne,y_utiles )    
perr = np.sqrt(np.diag(pcov))
valorRh= popt[0]
valorb=popt[1]

err_Rh = perr[0]
err_b=perr[1]

ajuste=sharp(x,valorRh,valorb)


plt.figure()
plt.grid()
plt.title("Sharp series Neón")
plt.ylabel("1/$\lambda$ [$m^{-1}$]")
plt.xlabel("1/$n^2$")
plt.scatter(xwlmax_Ne,y_utiles)
plt.plot(x,ajuste,c="red")


print("Rh=",valorRh,"+-",err_Rh,"en m^-1")
print("oo=",valorb,"+-",err_b)
print("proporcion valor dado con el real",valorRh/1.0973*10**(-7))
# Out:
# Rh= -1125335.0824979255 +- 129962.08152753304 en m^-1
# oo= 1850819.4478151186 +- 28251.915710434227
# proporcion valor dado con el real -0.10255491501849316

# %% [markdown]
# ### Hg Mercurio

# %% [markdown]
# ### Na Sodio

# %%
plt.close("all")
Z=1

os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\espectroscopia\Na')
#os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\espectroscopia')

file1='Sodio Filtro 3 482ms.csv'
file2='Sodio filtro 52 ms.csv'
file3='sodio sim filtro 16ms.csv'
file4='Sodio Sin Filtro 6ms.csv'


Na482= np.loadtxt(file1, delimiter=',', skiprows=0, unpack=True)
Na52=np.loadtxt(file2, delimiter=',', skiprows=0, unpack=True)
Na16=np.loadtxt(file3, delimiter=',', skiprows=0, unpack=True)
Na6=np.loadtxt(file4, delimiter=',', skiprows=0, unpack=True)

archivos=[Na482,Na52,Na16,Na6]
tiemposint=["482ms","52ms","16ms","6ms"]

j=0
k=0
for j in archivos:
     wl_Na=j[0]
     i_Na=j[1]
     

     plt.figure()
     plt.grid()
     plt.title(tiemposint[k])
     plt.plot(wl_Na,i_Na)
     plt.xlabel("Longitud de onda (nm)")
     plt.ylabel("Intensidad")
     k=k+1




wlmax_Na_utiles=[639.529, 632, 628.132, 623.127, 617.661, 611.074, 608.8]  #CAMBIAR SON DEL NE


#y_utiles=[10**(9)*1/639.529, 10**(9)*1/632, 10**(9)*1/628.132, 10**(9)*1/623.127, 10**(9)*1/617.661, 10**(9)*1/611.074, 10**(9)*1/608.8]
y_utiles=[ 10**(9)*1/632, 10**(9)*1/628.132, 10**(9)*1/623.127, 10**(9)*1/617.661, 10**(9)*1/611.074]  #CAMBIAR


x=np.linspace(0,0.15,8)
#


#xwlmax_Ne=[1/9**2, 1/8**2,1/7**2, 1/6**2, 1/5**2, 1/4**2, 1/3**2]
xwlmax_Na=[ 1/8**2,1/7**2, 1/6**2, 1/5**2, 1/4**2]   #CAMBIAR


def sharp(x,Rh,b):
          y=Rh*Z**2*(1/4-x)+b
          return y

popt, pcov = curve_fit(sharp, xwlmax_Na,y_utiles )    
perr = np.sqrt(np.diag(pcov))
valorRh= popt[0]
valorb=popt[1]

err_Rh = perr[0]
err_b=perr[1]

ajuste=sharp(x,valorRh,valorb)


plt.figure()
plt.grid()
plt.title("series Na")
plt.ylabel("1/$\lambda$ [$m^{-1}$]")
plt.xlabel("1/$n^2$")
plt.scatter(xwlmax_Na,y_utiles)
plt.plot(x,ajuste,c="red")


print("Rh=",valorRh,"+-",err_Rh,"en m^-1")
print("oo=",valorb,"+-",err_b)
print("proporcion valor dado con el real",valorRh/1.0973*10**(-7))
# Out:
# Rh= -1125335.0824979255 +- 129962.08152753304 en m^-1
# oo= 1850819.4478151186 +- 28251.915710434227
# proporcion valor dado con el real -0.10255491501849316

# %% [markdown]
# # Films

# %% [markdown]
# ## Spectrometro UV1000 probando ajuste 1/$\lambda$ AGREGAR ERRORES DEL APARATO

# %%
plt.close("all")
from scipy.stats import chisquare
m=100

def select_points(array, x):
    if x >= len(array):
        return array
    step = len(array) // x
    indices = np.arange(0, len(array), step)[:x]
    return array[indices]

def cs(n, y):
    return chisquare(n, np.sum(n)/np.sum(y) * y)

#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\films\spectrometro uv1000')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\films\spectrometro uv1000')

file1="20230310_Sample-01.txt"
file2="20230310_Sample-02.txt"
file3="20230310_Sample-03.txt"
file4="20230310_Sample-04.txt"
file5="20230310_Sample-05.txt"
file6="20230310_Sample-06.txt"
file7="20230310_Sample-07.txt"
file8="20230310_Sample-08.txt"
file9="20230310_Sample-09.txt"



# file1,file4=[[0.00178,1,0.584,0.1],[0.0708,1,0.243,0.1]]
# x=1/lambda
def absor(x,a,c,d,e):
          y=a*np.cos(2*np.pi*2*d*x)+c+e/x
          return y



titulos=["2000 RPM","3000 RPM","4000 RPM","4500 RPM","5000 RPM","6000 RPM"]
#todos los tits "2000 $rpm$","3000 $rpm$","4000 $rpm$","5000 $rpm$","6000 $rpm$","6000 $rpm$ bis","2000 $rpm$ bis(meado)","3500 $rpm$(meado)","4500 $rpm$"


a1=[1200,1200,1200,1100,1000,1000]  #1200,1200,1200,1000,1000,1000,1200,1200,1100

init_vals=[[1,0,30000,1],[0.002,0,18000,1],[1,0,14000,1],[1,0,12000,1],[1,0,11000,1],[1,0,9500,1]]            

#todos los init vals [1,0,30000,1],[0.002,0,18000,1],[1,0,14000,1],[1,0,11000,1],[1,0,10000,1],[1,0,10000,1],[1,0,33000,1],[1,0,23500,1],[1,0,12000,1]

print("MAQUINA")
espesores=[]
errores_espesores=[]

k=0
for j in [file1,file2,file3,file9,file4,file5]:   #todos file1,file2,file3,file4,file5,file6,file7,file8,file9
    film= np.loadtxt(j, delimiter=',', skiprows=2, unpack=True)
    a=a1[k]    #en 1000 servia
    b=1400

    
    abs=film[1]
    abs=abs[a:b]
    errabs=select_points(abs,m)
    wl=film[0]   #en nm
    wl=wl[a:b]
    errwl=select_points(wl,m) 
    
    wlerr=wl*0+0.3
    x_err=wlerr/wl**2
    errx_err=select_points(x_err,m)

    abserr=abs*0.01
    errabserr=select_points(abserr,m)
    
    popt, pcov = curve_fit(absor, 1/wl, abs,p0=init_vals[k],sigma=abserr)       #,p0=init_vals[k]
    perr = np.sqrt(np.diag(pcov))

    valora= popt[0]
    valorc=popt[1]
    valord=popt[2]
    valore=popt[3]
    
    err_a = perr[0]
    err_c = perr[1]
    err_d=perr[2]
    err_e=perr[3]


    observed=abs
    expected=absor(1/wl,valora,valorc,valord,valore)
     
   

    chisqr1=cs(observed,expected)

    print(k+1,titulos[k],"con d=",valord,"+-",err_d," con un chisqr reducido de=",chisqr1[0]/len(1/wl))

    espesores.append(valord)
    errores_espesores.append(err_d)
    
 
    
    ajuste= absor(1/wl,valora,valorc,valord,valore)
    
    plt.figure()
    plt.grid()
    plt.title(titulos[k])
    plt.ylabel("Absorbancia")
    plt.xlabel("1/$\lambda$ [1/nm]")
    plt.plot(1/wl,abs,linewidth=0.2)
    plt.errorbar(1/wl,abs,markersize=0.01,c="Black",fmt="o",label="Datos",yerr=abserr,xerr=x_err)
    plt.plot(1/wl,ajuste,c="red",label="Ajuste con coseno",zorder=2)
    #plt.scatter(1/wl,abs,c="black",zorder=4,s=1,label="Datos")
    plt.legend()
    k=k+1


print(espesores)



rpm=[2000,3000,4000,4500,5000,6000]
err_rpm=[2,2,2,2,2,2]

def inv(x,a3,b3):
          y=a3/np.sqrt(x)+b3
          return y
   



popt, pcov = curve_fit(inv, rpm, espesores)       #,p0=init_vals1
perr = np.sqrt(np.diag(pcov))

valora1= popt[0]
valorb1=popt[1]


err_a1 = perr[0]
err_b1 = perr[1]


#print("valores inversa",valora1,valorb1)
bins=np.linspace(rpm[0],rpm[-1],100)

ajuste1= inv(bins,valora1,valorb1)




observed=espesores
expected=inv(rpm,valora1,valorb1)
     
def cs(n, y):
    return chisquare(n, np.sum(n)/np.sum(y) * y)

chisqr1=cs(observed,expected)


print("chisqr reducido de rpmvsespesor=",chisqr1[0]/len(espesores))


plt.figure()
plt.grid()
plt.title("RPM vs Espesor (nm)")
plt.ylabel("Espesor (nm)")
plt.xlabel("RPM")
#plt.scatter(rpm,espesores,linewidth=1,label="Datos",color="Blue")
plt.errorbar(rpm,espesores,c="blue",yerr=errores_espesores,fmt="o",label="Datos",linewidth=1,markersize=3,xerr=err_rpm)  #agregar errores en y del manual del spin coater
plt.plot(bins,ajuste1,c="red",label="Ajuste con inversa")
plt.legend()
# Out:
# MAQUINA
# 1 2000 RPM con d= 29414.12461198621 +- 5.905486471045777  con un chisqr reducido de= -5.4663349955847214e-05
# 2 3000 RPM con d= 17960.94258607339 +- 0.8692395718341869  con un chisqr reducido de= -4.035637126638348e-06
# 3 4000 RPM con d= 14040.52425092377 +- 0.8384240794184395  con un chisqr reducido de= -4.960777559470723e-07
# 4 4500 RPM con d= 11942.02497386838 +- 0.9008704057088477  con un chisqr reducido de= -4.035209160024148e-06
# 5 5000 RPM con d= 10937.275916536786 +- 1.0174693082344823  con un chisqr reducido de= -3.3631038854728595e-05
# 6 6000 RPM con d= 9586.094608350491 +- 0.5024224968335338  con un chisqr reducido de= -1.3504983201958957e-05
# [29414.12461198621, 17960.94258607339, 14040.52425092377, 11942.02497386838, 10937.275916536786, 9586.094608350491]
# chisqr reducido de rpmvsespesor= 71.25806733974781

# %% [markdown]
# ## Nuestro setup

# %%
plt.close("all")

#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\films\nuestro setup')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\films\nuestro setup')



file00="vacio vacio 1ms.txt"
file0="vidriobien 1ms.csv"
file1="film1 1ms.csv"
file2="film2 1ms.csv"
file3="film3 1ms.csv"
file4="film4 1ms.csv"
file5="film5 1ms.txt"
file9="film9 1ms.txt"


vidrio=np.loadtxt(file0, delimiter=',', skiprows=0, unpack=True)
vacio=np.loadtxt(file00, delimiter=',', skiprows=0, unpack=True)


i00=vacio[1]
i0=vidrio[1]
#file1,file2,file3,file4,file5,file6,file7,file8,file9,file10

#init_vals=[[1,0,30000,1],[0.002,0,18000,1],[1,0,14000,1],[1,0,12000,1],[1,0,11000,1],[1,0,10000,1]]  

def absor(x,a,c,d,e):
          y=a*np.cos(2*np.pi*2*d*x)+c+e/x
          return y


titulos=["2000 RPM","3000 RPM","4000 RPM","4500 RPM","5000 RPM","6000 RPM"]
#todos los tits "2000 $rpm$","3000 $rpm$","4000 $rpm$","5000 $rpm$","6000 $rpm$","6000 $rpm$ bis","2000 $rpm$ bis(meado)","3500 $rpm$(meado)","4500 $rpm$"


a1=[3100,3100,3100,2900,2700,2700]  #1200,1200,1200,1000,1000,1000,1200,1200,1100

init_vals=[[1,0,30000,1],[0.002,0,18000,1],[1,0,14000,1],[1,0,12000,1],[1,0,11000,1],[1,0,10000,1]]            

#todos los init vals [1,0,30000,1],[0.002,0,18000,1],[1,0,14000,1],[1,0,11000,1],[1,0,10000,1],[1,0,10000,1],[1,0,33000,1],[1,0,23500,1],[1,0,12000,1]

print("NUESTRO SETUP")
espesores=[]
errores_espesores=[]

k=0
for j in [file1,file2,file3,file9,file4,file5]:
    film= np.loadtxt(j, delimiter=',', skiprows=0, unpack=True)
    a=a1[k]
    b=3400

    i00=vacio[1]
    i0=vidrio[1]

    i0=i0[a:b]
    i00=i00[a:b]
    i=film[1]
    i=i[a:b]
    wl=film[0]
    wl=wl[a:b]

    i_err=i*0.02
    i0_err=i0*0.02
    i00_err=i00*0.02

    wlerr=wl*0+0.2
    x_err=wlerr/wl**2

    #print(len(i),",",len(i0))

    division=(i-i0)/i00

    y=-np.log(division)

    y[np.isnan(y)] = 3.5
    
    err_y= --np.abs(i0_err/(i )) +np.abs(i_err/(i ))--np.abs(i00_err/i00)  #+ np.abs(i0_err/(i - i0)) +np.abs(i_err/(i - i0))+np.abs(i00_err/i00) 

    popt, pcov = curve_fit(absor, 1/wl, y,p0=init_vals[k])    
    perr = np.sqrt(np.diag(pcov))

    valora= popt[0]
    valorc=popt[1]
    valord=popt[2]
    valore=popt[3]
    
    
    err_a = perr[0]
    err_c = perr[1]
    err_d=perr[2]
    err_e=perr[3]
 
    observed=y
    expected=absor(1/wl,valora,valorc,valord,valore)
     
   
    chisqr1=cs(observed,expected)

    print(k+1,"para",titulos[k],"d=",valord,"+-",err_d," con un chisqr reducido de=",chisqr1[0]/len(1/wl))
    #print("para",titulos[k],"d=",valord)
    
    ajuste= absor(1/wl,valora,valorc,valord,valore)
    
    plt.figure()
    plt.grid()
    plt.title(titulos[k])
    plt.ylabel("Absorbancia")
    plt.xlabel("1/$\lambda$ [1/nm]")
    plt.errorbar(1/wl,y,xerr=x_err,yerr=err_y,c="black",fmt="o",markersize=0.1,label="Datos")
    plt.plot(1/wl,y,c="blue",linewidth=0.8)
    plt.scatter(1/wl,y,s=2,c="black",zorder=4)
    plt.plot(1/wl,ajuste,c="red",label="Ajuste con coseno",zorder=3,linewidth=5)
    plt.legend()
    k=k+1
# Out:
# NUESTRO SETUP
# 1 para 2000 RPM d= 30076.286130402874 +- 48.37118713482729  con un chisqr reducido de= 0.1727356047430766
# 2 para 3000 RPM d= 17428.90198274784 +- 138.82951315705012  con un chisqr reducido de= 0.2515889648302203
# C:\Users\NICOLS~1\AppData\Local\Temp/ipykernel_21244/2845633688.py:74: RuntimeWarning: invalid value encountered in log
#   y=-np.log(division)
# C:\Users\NICOLS~1\AppData\Local\Temp/ipykernel_21244/2845633688.py:74: RuntimeWarning: invalid value encountered in log
#   y=-np.log(division)
# C:\Users\NICOLS~1\AppData\Local\Temp/ipykernel_21244/2845633688.py:74: RuntimeWarning: invalid value encountered in log
#   y=-np.log(division)
# 3 para 4000 RPM d= 13659.035907777508 +- 57.042495724728134  con un chisqr reducido de= 0.20783144034642295
# 4 para 4500 RPM d= 11944.15799086276 +- 7.6581262708911595  con un chisqr reducido de= 0.12411714847502628
# 5 para 5000 RPM d= 11122.256543399579 +- 8.127319971039391  con un chisqr reducido de= 0.08672922413468918
# ...

# %% [markdown]
# # Fluorescencia

# %% [markdown]
# ## Rodamina

# %%
plt.close("all")


#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\FRET\rodamina')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\difractiva\codigos\FRET\rodamina')

file0='halogena 1ms vacio.csv'
file1='halogena 1ms rod.csv'



vacio= np.loadtxt(file0, delimiter=',', skiprows=0, unpack=True)
rod=np.loadtxt(file1, delimiter=',', skiprows=0, unpack=True)

x=vacio[0]
x_err=x*0+1

y=vacio[1]-rod[1]
y_err=y*0.04

plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Espectro de absorción Rodamina")
plt.errorbar(x,y,c="blue",markersize=0.5,xerr=x_err,yerr=y_err,fmt="o",zorder=3,label="Datos")
plt.plot(x,y,c="blue",linewidth=0.3,zorder=4)
plt.axvline(x=550.7,linewidth=2,c="green",label="Pico 550.7 nm")
plt.axvline(x=963.0,linewidth=2,c="red",label="Pico 963.0 nm")
plt.legend()

####LASER VERDE


def replace_interval(arr, start_idx, end_idx, x):
    for i in range(start_idx, end_idx+1):
        arr[i] = x
    return arr

file11='laser verde 20ms rod pot 0.04 low.csv'
file22='laser verde 20ms rod pot 0.04.csv'
file33='laser verde 20ms rod pot 0.06.csv'
a=1600
b=2300
a=0
b=3648
for j in [file33]:
    rod2=np.loadtxt(j, delimiter=',', skiprows=0, unpack=True)

    x2=rod2[0]   #wl
    #x2=x2[a:b]
    x2_err=x*0+0.2
    #x2_err=x2_err[a:b]
    y2=rod2[1]  #intensidad
    y2=replace_interval(y2,1553,1614,7.037845999e-02)
    y2=replace_interval(y2,2517,3160,7.283820957e-02)
    #y2=y2[a:b]
    y2_err=y*0.02
    #y2_err=y2_err[a:b]



    

    plt.figure()
    plt.grid()
    plt.xlabel("Longitud de onda (nm)")
    plt.ylabel("Intensidad")
    plt.title("Espectro de emisión de la rodamina")
    plt.plot(x2,y2,c="blue",linewidth=0.5,zorder=4)
    plt.errorbar(x2,y2,c="blue",markersize=0.5,xerr=x2_err,yerr=y2_err,fmt="o",zorder=3,label="Datos")
    plt.axvline(x=569.1,linewidth=1,c="green",label="Pico 569.1 nm")
    plt.axvline(x=717.2,linewidth=1,c="red",label="Pico 717.2 nm")
    plt.axvline(x=978.4,linewidth=1,c="red",label="Pico 978.4 nm")
    plt.legend()

    wlrod_laser=x2
    wlrod_err=x2_err

    intensrod_laser=y2
    intensrod_laser_err=y2_err

inc=1000
fin=2400
y=y*3/0.9
x=x[inc:fin]
x_err=x_err[inc:fin]
y_err=y_err*3/0.9
y=y[inc:fin]
y_err=y_err[inc:fin]
y_err=y_err/0.9

x2=x2[inc:fin]
x2_err=x2_err[inc:fin]
y2=y2[inc:fin]
y2=y2/0.9
y2_err=y2_err[inc:fin]
y2_err=y2_err/0.9
###PLOTEO TODO JUNTO
plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Espectros de la Rodamina")   #"Fluoresceína con láser violeta"
plt.plot(x2,y2,c="red",linewidth=0.1,zorder=4)
plt.errorbar(x2,y2,c="red",markersize=0.1,xerr=x2_err,yerr=y2_err,fmt="o",label="Emisión")
plt.plot(x,y,c="blue",linewidth=0.1,zorder=4)
plt.errorbar(x,y,c="blue",markersize=0.1,xerr=x_err,yerr=y_err,fmt="o",label="Absorción")
plt.axvline(x=569.1,linewidth=2,c="grey",label="Pico de emisión en 569.1 nm")
plt.axvline(x=550.7,linewidth=2,c="black",label="Pico de absorción en 550.7 nm")
plt.legend(loc=2)

# %% [markdown]
# ## Fluoresceína

# %%
plt.close("all")


#os.chdir (r'C:\Users\Sergio\Desktop\labo5\difractiva\codigos\FRET\fluorescina')
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\\difractiva\codigos\FRET\fluorescina')

file0='halogena 1ms vacio.csv'
file1='halogena 1ms fluo.csv'



vacio= np.loadtxt(file0, delimiter=',', skiprows=0, unpack=True)
fluo=np.loadtxt(file1, delimiter=',', skiprows=0, unpack=True)


x=vacio[0]
x_err=x*0+0.2

y=vacio[1]-fluo[1]
y_err=y*0.04

plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Espectro de absorción de la Fluoresceína")
plt.plot(x,y,c="blue",linewidth=0.5,zorder=4)
plt.axvline(x=506.4,linewidth=2,c="green",label="Pico 506.4 nm")
plt.axvline(x=735.5,linewidth=2,c="red",label="Pico 735.5 nm")
plt.axvline(x=963.4,linewidth=2,c="red",label="Pico 963.4 nm")
plt.errorbar(x,y,c="blue",markersize=0.5,xerr=x_err,yerr=y_err,fmt="o",zorder=3,label="Datos")
plt.legend()



####LASER VIOLETA

def replace_interval(arr, start_idx, end_idx, x):
    for i in range(start_idx, end_idx+1):
        arr[i] = x
    return arr
filemal='laser violeta 300ms fluo.txt'
file11='laser violeta 1300ms fluo.txt'
file22='laser violeta 800ms fluo.txt'

for j in [file11]:

    fluo2=np.loadtxt(j, delimiter=',', skiprows=0, unpack=True)

    x2=fluo2[0]   #wl
    x2_err=x2*0+0.2

    y2=fluo2[1]  #intensidad

    y2=replace_interval(y2,990,1025,7.916306145e-03)

    y2_err=y2*0.02

    


    plt.figure()
    plt.grid()
    plt.xlabel("Longitud de onda (nm)")
    plt.ylabel("Intensidad")
    plt.title(j)   #"Fluoresceína con láser violeta"
    plt.plot(x2,y2,c="blue",linewidth=0.5,zorder=4)
    plt.errorbar(x2,y2,c="blue",markersize=0.5,xerr=x2_err,yerr=y2_err,fmt="o",zorder=3,label="Datos")
    plt.legend()

    wlfluo_laser=x2
    wlfluo_err=x2_err

    intensfluo_laser=y2
    intensfluo_laser_err=y2_err

inc=1000
fin=2400
y=y*7/0.6
x=x[inc:fin]
x_err=x_err[inc:fin]
y_err=y_err*7/0.6
y=y[inc:fin]
y_err=y_err[inc:fin]

x2=x2[inc:fin]
x2_err=x2_err[inc:fin]
y2=y2[inc:fin]
y2=y2/0.6
y2_err=y2_err[inc:fin]
y2_err=y2_err/0.6
###PLOTEO TODO JUNTO
plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Espectros de la Fluoresceína")   #"Fluoresceína con láser violeta"
plt.plot(x2,y2,c="red",linewidth=0.1,zorder=4)
plt.errorbar(x2,y2,c="red",markersize=0.1,xerr=x2_err,yerr=y2_err,fmt="o",zorder=3,label="Emisión")
plt.plot(x,y,c="blue",linewidth=0.1,zorder=4)
plt.errorbar(x,y,c="blue",markersize=0.1,xerr=x_err,yerr=y_err,fmt="o",zorder=3,label="Absorción")
plt.axvline(x=521.5,linewidth=2,c="grey",label="Pico de emisión en 521.5 nm")
plt.axvline(x=506.4,linewidth=2,c="black",label="Pico de absorción en 506.4 nm")
plt.legend()

# %% [markdown]
# ## comparando resultados

# %%
plt.close("all")
## primero normalizo los resultados, ya que la rodamina la adquirimos con 20ms de tiempo de integracion y la fluoresceina con 1300ms entonces MAL 
# FALTA NORMALIZAR POR POTENCIA
intensfluo_lasernorm=intensfluo_laser/65
intensfluo_laser_errnorm=intensfluo_laser_err/65



plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Comparación")   #"Fluoresceína con láser violeta"
plt.plot(wlfluo_laser,intensfluo_lasernorm,c="red",linewidth=1,label="Fluoresceína")
plt.plot(wlrod_laser,intensrod_laser,c="orange",linewidth=1,label="Rodamina")
#plt.errorbar(x2,y2,c="blue",markersize=0.5,xerr=x2_err,yerr=y2_err,fmt="o",zorder=3,label="Datos")
plt.legend()

# %% [markdown]
# ## SOLUCIÓN 100ms

# %%
plt.close("all")
os.chdir (r'C:\Users\Nicolás Molina\Desktop\L5\\difractiva\codigos\FRET\solucion')

file0='rod 100ms c MQ.txt'
file1='fluo 100ms c MQ.txt'
file2='1000 fluo-200 rod -100ms.txt'
file3='1000 fluo-400 rod -100ms.txt'
file4='1000 fluo-600 rod -100ms.txt'
file5='1000 fluo-800 rod -100ms.txt'


def select_points(array, x):
    if x >= len(array):
        return array
    step = len(array) // x
    indices = np.arange(0, len(array), step)[:x]
    return array[indices]

rod=np.loadtxt(file0, delimiter=',', skiprows=0, unpack=True)
fluo=np.loadtxt(file1, delimiter=',', skiprows=0, unpack=True)

xr=rod[0]   #wl
errxr=select_points(xr,100) #pongo err al principio de los arrays para los errores
xr_err=xr*0+0.2
errxr_err=select_points(xr_err,100)

yr=rod[1]  #intensidad
erryr=select_points(yr,100)
yr_err=yr*0.02
erryr_err=select_points(yr_err,100)

xf=fluo[0]   #wl
errxf=select_points(xf,100)
xf_err=xf*0+0.2
errxf_err=select_points(xf_err,100)

yf=fluo[1]  #intensidad
erryf=select_points(yf,100)
yf_err=yf*0.02
erryf_err=select_points(yf_err,100)

plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Muestras solas, iluminadas por láser violeta")   
#plt.plot(xr,yr,c="red",linewidth=0.5,zorder=4,label="Rodamina")
#plt.plot(xf,yf,c="blue",linewidth=0.5,zorder=4,label="Rodamina")
plt.errorbar(xr,yr,c="red",markersize=0.5,xerr=xr_err,yerr=yr_err,fmt="o",label="Rodamina")
plt.errorbar(xf,yf,c="blue",markersize=0.5,xerr=xf_err,yerr=yf_err,fmt="o",label="Fluoresceína")
plt.legend()

inc=1100
fin=2500

xr=xr[inc:fin]
yr=yr[inc:fin]
xr_err=xr_err[inc:fin]
yr_err=yr_err[inc:fin]

xf=xf[inc:fin]
yf=yf[inc:fin]
xf_err=xf_err[inc:fin]
yf_err=yf_err[inc:fin]

file6="solucion 170ms.txt"
sol6=np.loadtxt(file6, delimiter=',', skiprows=0, unpack=True)
x6=sol6[0]   #wl
x6=x6[inc:fin]


x6_err=x6*0+0.2
    

y6=sol6[1]  #intensidad
y6=y6[inc:fin]
y6_err=y6*0.02
y6=y6*0.588



tituloss=["Solución: 1000 $\mu$L de Flu y 200 $\mu$L de R6G","a","b","c"]
soluciones=["1000 $\mu$L de Flu y 200 $\mu$L de R6G","1000 $\mu$L de Flu y 400 $\mu$L de R6G","1000 $\mu$L de Flu y 600 $\mu$L de R6G","1000 $\mu$L de Flu y 800 $\mu$L de R6G","1000 $\mu$L de Flu y 1000 $\mu$L de R6G"]
k=0
for j in [file2,file3,file4,file5]:

    sol=np.loadtxt(j, delimiter=',', skiprows=0, unpack=True)

    x=sol[0]   #wl
    x=x[inc:fin]
    
    x_err=x*0+0.2
    
    

    y=sol[1]  #intensidad
    y=y[inc:fin]
    y_err=y*0.02
    

    plt.figure()
    plt.grid()
    plt.xlabel("Longitud de onda (nm)")
    plt.ylabel("Intensidad")
    plt.title(tituloss[k])   #"Fluoresceína con láser violeta"
    plt.plot(x,y,c="green",linewidth=0.5,zorder=4)
    plt.errorbar(x,y,c="green",markersize=1,xerr=x_err,yerr=y_err,fmt="o",zorder=3,label="Solución")
    plt.plot(xr,yr,c="red",linewidth=0.5,zorder=3)
    plt.errorbar(xr,yr,c="red",markersize=1,xerr=xr_err,yerr=yr_err,fmt="o",label="Rodamina en agua MQ")
    plt.plot(xf,yf,c="blue",linewidth=0.5,zorder=3)
    plt.errorbar(xf,yf,c="blue",markersize=1,xerr=xf_err,yerr=yf_err,fmt="o",label="Fluoresceína en agua MQ")
    plt.legend()



    k=k+1

plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Datos de muestra a misma cantidad de Rodamina")
plt.plot(xr,yr,linewidth=1,label="Rodamina")
plt.plot(xf,yf,linewidth=1,label="Fluoresceína")
plt.plot(x6,y6,linewidth=1,label="Solución 1000 $\mu$L de Flu y de R6G")
plt.legend(loc=2)
k=0

plt.figure()
plt.grid()
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Intensidad")
plt.title("Soluciones")
for j in [file2,file3,file4,file5]:

    sol=np.loadtxt(j, delimiter=',', skiprows=0, unpack=True)

    x=sol[0]   #wl
    x=x[inc:fin]
    
    x_err=x*0+0.2
    

    y=sol[1]  #intensidad
    y=y[inc:fin]
    y_err=y*0.02

    plt.plot(x,y,linewidth=1,label=soluciones[k])
    #plt.errorbar(x,y,markersize=1,xerr=x_err,yerr=y_err,fmt="-",label=soluciones[k])

    k=k+1
plt.plot(x6,y6,linewidth=1,label=soluciones[k])
plt.legend()

file77="eficiencia.txt"
efi=np.loadtxt(file77, delimiter=',', skiprows=1, unpack=True)

conc=efi[0]
efic=efi[1]

plt.figure()
plt.grid()
plt.scatter(conc,efic)
plt.xlabel("Concentración ($\mu$M)")
plt.ylabel("Eficiencia")
plt.title("Concentración vs Eficiencia")
# Out:
# Text(0.5, 1.0, 'Concentración vs Eficiencia')
